# %%
#annuity_transformers.ipynb
# Transformers for Annuity Text Analysis
# Use HuggingFace (add transformers to reqs) to summarize Athene disclosures.
from transformers import pipeline

summarizer = pipeline("summarization")
text = "Guarantees provided by annuities are subject to the financial strength..."  # From PDF disclosures
summary = summarizer(text, max_length=50)
print("Summary of Athene Disclosures:", summary[0]["summary_text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 #annuity_transformers.ipynb
#       2 # Transformers for Annuity Text Analysis
#       3 # Use HuggingFace (add transformers to reqs) to summarize Athene disclosures.
# ----> 4 from transformers import pipeline
#       6 summarizer = pipeline("summarization")
#       7 text = "Guarantees provided by annuities are subject to the financial strength..."  # From PDF disclosures
#
# ModuleNotFoundError: No module named 'transformers'
