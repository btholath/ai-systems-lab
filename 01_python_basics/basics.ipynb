# %%
print("AI Lab Ready!")
# Out:
# AI Lab Ready!

# %%
# Python Basics
## 1. Variables and Data Types
# Integer, float, string, boolean
x = 10
y = 3.14
name = "AI Lab"
is_active = True
print(x, y, name, is_active)
# Out:
# 10 3.14 AI Lab True

# %% [markdown]
# # Python Basics
# ## 1. Variables and Data Types
# ```python
# # Integer, float, string, boolean
# x = 10
# y = 3.14
# name = "AI Lab"
# is_active = True
# print(x, y, name, is_active)

# %% [markdown]
# # List operations
# fruits = ["apple", "banana", "cherry"]
# for fruit in fruits:
#     print(f"I like {fruit}")

# %%
# List operations
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like cherry

# %% [markdown]
# from data.annuity_data import athene_products, company_highlights# Variables: Premium examples from Athene AccuMax 7
# min_premium = athene_products[0]["min_premium"]  # 10000
# max_premium = athene_products[0]["max_premium"]  # 1000000
# print(f"Athene AccuMax 7 minimum premium: ${min_premium}")
#
# # Lists: Product features
# features = athene_products[0]["features"]
# print("Features:", features)
#
# # Loops: Iterate over rates
# for strategy, rate in athene_products[0]["rates"].items():
#     if isinstance(rate, dict):
#         print(f"{strategy} Low Band: {rate['low_band'] * 100}%")

# %%
#export PYTHONPATH=$PYTHONPATH:/workspaces/ai-systems-lab
import sys
import os
sys.path.append(os.path.abspath('/workspaces/ai-systems-lab'))
from data.annuity_data import athene_products, company_highlights

# Variables: Premium examples from Athene AccuMax 7
min_premium = athene_products[0]["min_premium"]  # 10000
max_premium = athene_products[0]["max_premium"]  # 1000000
print(f"Athene AccuMax 7 minimum premium: ${min_premium}")

# Lists: Product features
features = athene_products[0]["features"]
print("Features:", features)

# Loops: Iterate over rates
for strategy, rate in athene_products[0]["rates"].items():
    if isinstance(rate, dict):
        print(f"{strategy} Low Band: {rate['low_band'] * 100}%")
# Out:
# Athene AccuMax 7 minimum premium: $10000
# Features: ['Terminal Illness Waiver (not CA)', 'Confinement Waiver (not CA)', 'MVA (not CA)', 'Death Benefit: Greater of Interim Value or Min Guaranteed']
# 7-Yr PtP S&P 500 (Par Rate) Low Band: 88.0%
# 7-Yr PtP AIMAX (Par Rate) Low Band: 365.0%
# 7-Yr PtP CAPE (Par Rate) Low Band: 434.99999999999994%
# 7-Yr Annual Sum S&P (Par Rate) Low Band: 80.0%
# 1-Yr PtP AIMAX (Par Rate) Low Band: 150.0%
# 1-Yr PtP CAPE (Par Rate) Low Band: 145.0%
# Fixed Low Band: 3.45%

# %% [markdown]
# # Functions: Calculate potential growth
# def calculate_growth(premium, rate, years=7):
#     return premium * (1 + rate) ** years  # Simple compound for fixed rate example
#
# fixed_rate_high = athene_products[0]["rates"]["Fixed"]["high_band"]  # 0.0375
# growth = calculate_growth(100000, fixed_rate_high)
# print(f"Growth on $100,000 AccuMax 7 Fixed (High Band) over 7 years: ${growth:.2f}")

# %%
import sys
import os
sys.path.append(os.path.abspath('/workspaces/ai-systems-lab'))
from data.annuity_data import athene_products, company_highlights

# Functions: Calculate potential growth
def calculate_growth(premium, rate, years=7):
    return premium * (1 + rate) ** years  # Simple compound for fixed rate example

fixed_rate_high = athene_products[0]["rates"]["Fixed"]["high_band"]  # 0.0375
growth = calculate_growth(100000, fixed_rate_high)
print(f"Growth on $100,000 AccuMax 7 Fixed (High Band) over 7 years: ${growth:.2f}")
# Out:
# Growth on $100,000 AccuMax 7 Fixed (High Band) over 7 years: $129394.77
