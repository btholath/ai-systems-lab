# %%
# CNN for Annuity Charts (Optional)
# If images (e.g., from PDFs) are uploaded, analyze charts.
# Use OpenCV (add to reqs: opencv-python) to process screenshots of growth charts from 73007.pdf.
# Why? Process visual data from Athene brochures.
import cv2
# Assume 'growth_chart.png' from PDF page 5
img = cv2.imread('growth_chart.png')
# Simple edge detection for lines in chart
edges = cv2.Canny(img, 100, 200)
cv2.imwrite('edges.png', edges)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 # CNN for Annuity Charts (Optional)
#       2 # If images (e.g., from PDFs) are uploaded, analyze charts.
#       3 # Use OpenCV (add to reqs: opencv-python) to process screenshots of growth charts from 73007.pdf.
#       4 # Why? Process visual data from Athene brochures.
# ----> 5 import cv2
#       6 # Assume 'growth_chart.png' from PDF page 5
#       7 img = cv2.imread('growth_chart.png')
#
# ModuleNotFoundError: No module named 'cv2'
