# %% [markdown]
# # Use Pandas to create a DataFrame of products.
# import sys
# import os
# sys.path.append(os.path.abspath('/workspaces/ai-systems-lab'))
# from data.annuity_data import athene_products, company_highlights
# import pandas as pd
#
# df = pd.DataFrame(athene_products)
# print(df[["name", "min_premium", "max_premium", "type"]])
#
# # Filter high-premium products
# high_premiums = df[df["max_premium"] > 500000]
# print("Products with max premium > $500k:\n", high_premiums)
#
# # Visualize ratings
# ratings_df = pd.DataFrame([company_highlights["ratings"]]).T
# ratings_df.plot(kind="bar", title="Athene Financial Ratings")

# %%
# Use Pandas to create a DataFrame of products.
import sys
import os
sys.path.append(os.path.abspath('/workspaces/ai-systems-lab'))
from data.annuity_data import athene_products, company_highlights
import pandas as pd

df = pd.DataFrame(athene_products)
print(df[["name", "min_premium", "max_premium", "type"]])

# Filter high-premium products
high_premiums = df[df["max_premium"] > 500000]
print("Products with max premium > $500k:\n", high_premiums)

print(company_highlights["ratings"])

## Visualize ratings
#ratings_df = pd.DataFrame([company_highlights["ratings"]]).T
#ratings_df.plot(kind="bar", title="Athene Financial Ratings")

# Create a DataFrame with rating agencies and a constant value
import pandas as pd

ratings_data = {agency: 1 for agency in company_highlights["ratings"].keys()}
ratings_df = pd.DataFrame([ratings_data]).T
ratings_df.columns = ["Rating Presence"]

# Visualize ratings
ratings_df.plot(kind="bar", title="Athene Financial Ratings", legend=False)
# Out:
#         name  min_premium  max_premium                           type
# 0  AccuMax 7        10000      1000000          Fixed Indexed Annuity
# 1  MaxRate 7        10000      1000000  Multi-Year Guaranteed Annuity
# Products with max premium > $500k:
#          name                           type  min_premium  max_premium  \
# 0  AccuMax 7          Fixed Indexed Annuity        10000      1000000
# 1  MaxRate 7  Multi-Year Guaranteed Annuity        10000      1000000
#
#   issue_ages  withdrawal_charge_years  \
# 0       0-83                      7.0
# 1       0-83                      NaN
#
#                                    free_withdrawal  \
# 0  Greater of 10% Accumulated Value or 10% Premium
# 1                                              NaN
#
#                                                rates  \
# 0  {'7-Yr PtP S&P 500 (Par Rate)': {'low_band': 0...
# 1                                   {'Fixed': 0.045}
#
#                                             features  \
# 0  [Terminal Illness Waiver (not CA), Confinement...
# 1  [10% Free Withdrawal, Confinement/Terminal Wai...
#
#                 state_availability
# 0  All except NY; variations in CA
# 1                              NaN
# {'S&P': 'A+ (Jan 2024)', 'Fitch': 'A+ (Sep 2024)', 'AM Best': 'A+ (Jun 2024)', "Moody's": 'A1 (Sep 2024)'}
# <Axes: title={'center': 'Athene Financial Ratings'}>
